# %% [markdown]
# # Importing some useful libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Dataset from HuggingFace

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('SetFit/20_newsgroups')
# Out:
# Using custom data configuration SetFit--20_newsgroups-f9362e018b6adf67
# Found cached dataset json (/home/sysadm/.cache/huggingface/datasets/SetFit___json/SetFit--20_newsgroups-f9362e018b6adf67/0.0.0/e6070c77f18f01a5ad4551a8b7edfba20b8438b7cad4d94e6ad9378022ce4aab)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'label_text'],
#         num_rows: 11314
#     })
#     test: Dataset({
#         features: ['text', 'label', 'label_text'],
#         num_rows: 7532
#     })
# })

# %%
type(dataset)
# Out:
# datasets.dataset_dict.DatasetDict

# %% [markdown]
# # Sample Data

# %%
dataset['train'][0]
# Out:
# {'text': 'I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.',
#  'label': 7,
#  'label_text': 'rec.autos'}

# %% [markdown]
# # Checking number of instances of train and test

# %%
len(dataset['train'])
# Out:
# 11314

# %%
len(dataset['test'])
# Out:
# 7532

# %% [markdown]
# # Creating Train and Test Data

# %%
documents_train = []

for i in range(len(dataset['train'])):
    documents_train.append(dataset['train'][i]['text'])

# %%
dataset['train'][0]['text']
# Out:
# 'I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.'

# %%
documents_train[0]
# Out:
# 'I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.'

# %%
documents_test = []

for i in range(len(dataset['test'])):
    documents_test.append(dataset['test'][i]['text'])

# %%
documents_test[0]
# Out:
# 'I am a little confused on all of the models of the 88-89 bonnevilles.\nI have heard of the LE SE LSE SSE SSEI. Could someone tell me the\ndifferences are far as features or performance. I am also curious to\nknow what the book value is for prefereably the 89 model. And how much\nless than book value can you usually get them for. In other words how\nmuch are they in demand this time of year. I have heard that the mid-spring\nearly summer is the best time to buy.'

# %%
len(documents_train)
# Out:
# 11314

# %%
len(documents_test)
# Out:
# 7532

# %% [markdown]
# # Importing what we need

# %%
from contextualized_topic_models.models.ctm import CombinedTM
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessingStopwords
import nltk

# %% [markdown]
# # Preprocessing

# %%
from nltk.corpus import stopwords as stop_words

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/sysadm/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = list(stop_words.words("english"))

# %% [markdown]
# # Building the Model

# %%
sp = WhiteSpacePreprocessingStopwords(documents_train, stopwords_list=stopwords)

# %%
preprocessed_documents, unpreprocessed_corpus, vocab, retained_indices = sp.preprocess()
# Out:
# /home/sysadm/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Will try to identify posterior collapse

# %% [markdown]
# # Only Using "all-mpnet-base-v2" as PLM

# %%
tpa = TopicModelDataPreparation("all-mpnet-base-v2")

# %%
training_dataset1=tpa.fit(text_for_contextual=unpreprocessed_corpus, text_for_bow=preprocessed_documents)
# Out:
# /home/sysadm/anaconda3/lib/python3.9/site-packages/contextualized_topic_models/utils/data_preparation.py:57: UserWarning: the longest document in your collection has 11765 words, the model instead truncates to 128 tokens.
#   warnings.warn(f"the longest document in your collection has {max_local_length} words, the model instead "
# Batches:   0%|          | 0/55 [00:00<?, ?it/s]
# /home/sysadm/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Batch Size 32 and learning rate 10^-7

# %%
ctma1 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                  dropout=0.2, batch_size=32, lr=1e-7, solver='adam',
                  n_components=10, num_epochs=100)
ctma2 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                  dropout=0.2, batch_size=32, lr=1e-7, solver='adam',
                  n_components=20, num_epochs=100)
ctma3 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                  dropout=0.2, batch_size=32, lr=1e-7, solver='adam',
                  n_components=30, num_epochs=100)
ctma4 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                  dropout=0.2, batch_size=32, lr=1e-7, solver='adam',
                  n_components=50, num_epochs=100)
ctma5 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                  dropout=0.2, batch_size=32, lr=1e-7, solver='adam',
                  n_components=100, num_epochs=100)

# %%
ctma1.fit(training_dataset1)
ctma2.fit(training_dataset1) 
ctma3.fit(training_dataset1)
ctma4.fit(training_dataset1)
ctma5.fit(training_dataset1)
# Out:
# Epoch: [100/100]	 Seen Samples: [1094400/1095100]	Train Loss: 566.0066612199035	Time: 0:00:11.750636: : 100it [18:58, 11.38s/it]
# Sampling: [20/20]: : 20it [01:30,  4.50s/it]
# Epoch: [100/100]	 Seen Samples: [1094400/1095100]	Train Loss: 584.5583935118558	Time: 0:00:11.208517: : 100it [20:22, 12.22s/it]
# Sampling: [20/20]: : 20it [01:30,  4.55s/it]
# Epoch: [100/100]	 Seen Samples: [1094400/1095100]	Train Loss: 583.3190147890682	Time: 0:00:13.486770: : 100it [20:10, 12.11s/it]
# Sampling: [20/20]: : 20it [01:38,  4.91s/it]
# Epoch: [100/100]	 Seen Samples: [1094400/1095100]	Train Loss: 612.6710064090483	Time: 0:00:11.910460: : 100it [19:45, 11.85s/it]
# Sampling: [20/20]: : 20it [01:45,  5.26s/it]
# Epoch: [100/100]	 Seen Samples: [1094400/1095100]	Train Loss: 652.338473403663	Time: 0:00:12.320324: : 100it [20:35, 12.36s/it]
# Sampling: [20/20]: : 20it [01:36,  4.83s/it]

# %%
with open(r'preprocessed_documents.txt', 'w') as fp:
    for item in preprocessed_documents:
        # write each item on a new line
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done

# %%
from contextualized_topic_models.evaluation.measures import CoherenceNPMI
from contextualized_topic_models.evaluation.measures import TopicDiversity

# %%
with open('preprocessed_documents.txt', "r") as fr:
    texts = [doc.split() for doc in fr.read().splitlines()] # load text for NPMI

# %%
npmia1 = CoherenceNPMI(texts=texts, topics=ctma1.get_topic_lists(10)); a1 = npmia1.score(topk=10)
npmia2 = CoherenceNPMI(texts=texts, topics=ctma2.get_topic_lists(10)); a2 = npmia2.score(topk=10)
npmia3 = CoherenceNPMI(texts=texts, topics=ctma3.get_topic_lists(10)); a3 = npmia3.score(topk=10)
npmia4 = CoherenceNPMI(texts=texts, topics=ctma4.get_topic_lists(10)); a4 = npmia4.score(topk=10)
npmia5 = CoherenceNPMI(texts=texts, topics=ctma5.get_topic_lists(10)); a5 = npmia5.score(topk=10)

# %%
print(f"for 10 topics, the coherenceNPMI is {a1}")
print(f"for 20 topics, the coherenceNPMI is {a2}")
print(f"for 30 topics, the coherenceNPMI is {a3}")
print(f"for 50 topics, the coherenceNPMI is {a4}")
print(f"for 100 topics, the coherenceNPMI is {a5}")
# Out:
# for 10 topics, the coherenceNPMI is -0.26875313220350555
# for 20 topics, the coherenceNPMI is -0.24743953369429547
# for 30 topics, the coherenceNPMI is -0.2738088090824495
# for 50 topics, the coherenceNPMI is -0.24863943501846283
# for 100 topics, the coherenceNPMI is -0.2557335394061254

# %%
tda1 = TopicDiversity(topics=ctma1.get_topic_lists(10)); ta1 = tda1.score(topk=10)
tda2 = TopicDiversity(topics=ctma2.get_topic_lists(10)); ta2 = tda2.score(topk=10)
tda3 = TopicDiversity(topics=ctma3.get_topic_lists(10)); ta3 = tda3.score(topk=10)
tda4 = TopicDiversity(topics=ctma4.get_topic_lists(10)); ta4 = tda4.score(topk=10)
tda5 = TopicDiversity(topics=ctma5.get_topic_lists(10)); ta5 = tda5.score(topk=10)

# %%
print(f"for 10 topics, the TopicDiversity is {ta1}")
print(f"for 20 topics, the TopicDiversity is {ta2}")
print(f"for 30 topics, the TopicDiversity is {ta3}")
print(f"for 50 topics, the TopicDiversity is {ta4}")
print(f"for 100 topics, the TopicDiversity is {ta5}")
# Out:
# for 10 topics, the TopicDiversity is 0.95
# for 20 topics, the TopicDiversity is 0.93
# for 30 topics, the TopicDiversity is 0.9133333333333333
# for 50 topics, the TopicDiversity is 0.896
# for 100 topics, the TopicDiversity is 0.804

# %%
print(ctma1.get_topic_lists(k=5))
print("////")
print(ctma2.get_topic_lists(k=5))
print("////")
print(ctma3.get_topic_lists(k=5))
print("////")
print(ctma4.get_topic_lists(k=5))
print("////")
print(ctma5.get_topic_lists(k=5))
# Out:
# [['attempt', 'field', 'fight', 'rom', 'many'], ['drivers', 'woman', 'forces', 'meeting', 'interface'], ['robert', 'mailing', 'natural', 'says', 'woman'], ['gets', 'issue', 'fight', 'hey', 'ah'], ['playing', 'uk', 'numbers', 'kept', 'organizations'], ['place', 'zone', 'replies', 'sometimes', 'company'], ['individual', 'hands', 'minnesota', 'mc', 'break'], ['nobody', 'events', 'player', 'feature', 'converter'], ['ftp', 'places', 'begin', 'quality', 'differences'], ['variety', 'distribution', 'hardware', 'mhz', 'prices']]
# ////
# [['supply', 'memory', 'sp', 'air', 'obtained'], ['going', 'transfer', 'eof', 'table', 'impossible'], ['armenian', 'seriously', 'terms', 'willing', 'matter'], ['moved', 'hello', 'assuming', 'tl', 'ray'], ['colors', 'merely', 'atheist', 'oname', 'lead'], ['week', 'bring', 'air', 'appreciated', 'washington'], ['stick', 'best', 'cpu', 'check', 'europe'], ['along', 'eternal', 'pu', 'later', 'tom'], ['saying', 'militia', 'criminal', 'ed', 'max'], ['eye', 'season', 'bible', 'nations', 'penalty'], ['exact', 'tank', 'generation', 'totally', 'fear'], ['reality', 'supposed', 'mt', 'said', 'apr'], ['must', 'cpu', 'spot', 'anyway', 'built'], ['interface', 'know', 'sin', 'always', 'contain'], ['makes', 'secret', 'reported', 'language', 'oh'], ['twice', 'reply', 'break', 'mission', 'box'], ['screen', 'base', 'poor', 'major', 'copy'], ['di', 'criminal', 'ii', 'claim', 'died'], ['week', 'ron', 'feet', 'form', 'enforcement'], ['hurt', 'jesus', 'everyone', 'civilians', 'fonts']]
# ////
# [['battery', 'writes', 'former', 'near', 'obtained'], ['qy', 'input', 'kn', 'resolution', 'telling'], ['attacks', 'complex', 'brought', 'listen', 'agree'], ['instance', 'number', 'card', 'active', 'cut'], ['team', 'caught', 'apr', 'shell', 'output'], ['difficult', 'essentially', 'please', 'cost', 'seem'], ['em', 'individual', 'routines', 'published', 'location'], ['though', 'gm', 'resource', 'stay', 'sx'], ['fault', 'rsa', 'exactly', 'remote', 'americans'], ['sunday', 'ww', 'leafs', 'ii', 'twice'], ['usr', 'view', 'engineering', 'knowledge', 'reach'], ['pittsburgh', 'behavior', 'sk', 'months', 'near'], ['flames', 'safety', 'appreciate', 'ad', 'data'], ['installed', 'block', 'bxn', 'various', 'drugs'], ['christianity', 'produce', 'pictures', 'normal', 'good'], ['needed', 'remember', 'dy', 'administration', 'slave'], ['manager', 'claimed', 'encrypted', 'mw', 'nearly'], ['lost', 'default', 'plane', 'minor', 'israel'], ['step', 'stand', 'separate', 'dollars', 'edu'], ['sold', 'everything', 'proposed', 'posts', 'east'], ['produced', 'armed', 'peace', 'soviet', 'users'], ['kind', 'another', 'writes', 'properly', 'oname'], ['clear', 'become', 'canada', 'usually', 'say'], ['turkey', 'frame', 'scx', 'lunar', 'si'], ['released', 'price', 'armenian', 'research', 'output'], ['chip', 'stay', 'recognize', 'apr', 'yd'], ['knowing', 'formats', 'child', 'fan', 'master'], ['baseball', 'mouse', 'independent', 'network', 'different'], ['instance', 'weapon', 'pub', 'documentation', 'secure'], ['pub', 'instead', 'serial', 'japanese', 'asked']]
# ////
# [['early', 'blood', 'stop', 'message', 'type'], ['want', 'agencies', 'create', 'remove', 'compare'], ['puck', 'alternative', 'bay', 'fun', 'cache'], ['latest', 'windows', 'turned', 'mass', 'replace'], ['postscript', 'christian', 'zone', 'rlk', 'etc'], ['thus', 'social', 'fixed', 'clear', 'period'], ['significant', 'existing', 'mostly', 'decent', 'copies'], ['somebody', 'late', 'person', 'choice', 'federal'], ['recent', 'front', 'motif', 'keyboard', 'cj'], ['insurance', 'lived', 'defined', 'regular', 'christians'], ['couple', 'objective', 'week', 'anyway', 'recently'], ['creation', 'search', 'requirements', 'newsgroup', 'positive'], ['life', 'pittsburgh', 'home', 'sites', 'slot'], ['new', 'posted', 'co', 'set', 'story'], ['simple', 'check', 'plus', 'sec', 'oname'], ['throw', 'money', 'form', 'put', 'middle'], ['ball', 'copies', 'justice', 'internal', 'race'], ['small', 'nb', 'modern', 'hundred', 'changes'], ['god', 'first', 'yd', 'lord', 'actually'], ['muslim', 'protect', 'jim', 'direction', 'loss'], ['east', 'couple', 'events', 'gif', 'main'], ['uww', 'israeli', 'organizations', 'expensive', 'americans'], ['faith', 'back', 'hit', 'cards', 'sys'], ['word', 'long', 'yeah', 'secretary', 'onto'], ['companies', 'next', 'argue', 'six', 'lack'], ['god', 'gives', 'playing', 'family', 'cross'], ['fonts', 'bike', 'logic', 'humans', 'mail'], ['members', 'sj', 'current', 'sort', 'pu'], ['personally', 'gone', 'surface', 'listed', 'try'], ['addition', 'spirit', 'co', 'road', 'default'], ['ibm', 'using', 'ml', 'solution', 'entry'], ['pts', 'answer', 'brother', 'exists', 'press'], ['wants', 'project', 'session', 'regarding', 'em'], ['meaning', 'way', 'died', 'four', 'version'], ['clinton', 'members', 'companies', 'connect', 'appreciate'], ['control', 'third', 'process', 'simply', 'available'], ['manufacturers', 'reduce', 'index', 'al', 'level'], ['select', 'running', 'required', 'frequently', 'images'], ['anybody', 'michael', 'chicago', 'everything', 'mw'], ['engineering', 'pass', 'oh', 'proposal', 'company'], ['firearm', 'shows', 'point', 'string', 'mf'], ['board', 'begin', 'players', 'difficult', 'laws'], ['expect', 'muslim', 'replace', 'religious', 'wall'], ['called', 'default', 'space', 'york', 'worse'], ['form', 'lib', 'bus', 'canadian', 'paid'], ['nj', 'contains', 'fixed', 'went', 'animals'], ['questions', 'could', 'made', 'driver', 'result'], ['areas', 'art', 'causes', 'thank', 'bottom'], ['fun', 'religions', 'least', 'bits', 'nobody'], ['rest', 'official', 'resource', 'health', 'new']]
# ////
# [['unix', 'converter', 'cal', 'em', 'foreign'], ['straight', 'jewish', 'announced', 'bxn', 'views'], ['moved', 'complete', 'record', 'pre', 'independent'], ['disk', 'tu', 'surface', 'note', 'security'], ['paul', 'phone', 'nobody', 'firearms', 'low'], ['positive', 'organization', 'fully', 'published', 'expansion'], ['ho', 'author', 'available', 'appears', 'militia'], ['bob', 'division', 'pointed', 'flyers', 'really'], ['computers', 'th', 'amount', 'setting', 'sell'], ['wiring', 'joe', 'stephanopoulos', 'easier', 'nj'], ['older', 'choice', 'md', 'change', 'often'], ['follow', 'satellite', 'used', 'joe', 'water'], ['english', 'fan', 'clearly', 'game', 'ra'], ['following', 'technology', 'gc', 'articles', 'seeing'], ['resolution', 'equipment', 'king', 'offer', 'pm'], ['buf', 'leaders', 'gave', 'keyboard', 'us'], ['individuals', 'industry', 'fault', 'previous', 'developed'], ['generally', 'rate', 'si', 'foundation', 'today'], ['boston', 'drug', 'activities', 'size', 'increased'], ['person', 'gets', 'islam', 'looks', 'putting'], ['particularly', 'released', 'sell', 'give', 'hd'], ['order', 'selling', 'replies', 'proper', 'considering'], ['giving', 'found', 'quoted', 'hp', 'extremely'], ['missed', 'board', 'court', 'tq', 'foundation'], ['fp', 'citizens', 'cover', 'methods', 'hurt'], ['statement', 'future', 'un', 'hockey', 'israel'], ['interested', 'agents', 'nations', 'together', 'des'], ['cryptography', 'circuit', 'holy', 'meet', 'straight'], ['directly', 'implementation', 'love', 'fan', 'space'], ['fun', 'feature', 'cut', 'true', 'western'], ['fairly', 'major', 'bush', 'different', 'long'], ['joe', 'understand', 'cannot', 'advantage', 'philadelphia'], ['understand', 'quote', 'newsgroup', 'better', 'led'], ['seconds', 'digital', 'discuss', 'thing', 'perhaps'], ['across', 'seems', 'anonymous', 'five', 'contains'], ['safe', 'tells', 'larry', 'saw', 'supported'], ['models', 'still', 'em', 'give', 'result'], ['catholic', 'rec', 'push', 'ten', 'try'], ['master', 'hello', 'civil', 'pressure', 'hole'], ['database', 'save', 'ibm', 'lie', 'entirely'], ['history', 'st', 'action', 'um', 'stupid'], ['add', 'matthew', 'using', 'capable', 'fixed'], ['spacecraft', 'chips', 'personal', 'goals', 'dr'], ['kh', 'makes', 'modern', 'lost', 'cheap'], ['xterm', 'regards', 'similar', 'si', 'multiple'], ['makes', 'listed', 'distribution', 'back', 'poor'], ['release', 'offers', 'authors', 'logic', 'pin'], ['location', 'pittsburgh', 'purposes', 'expected', 'structure'], ['motif', 'rk', 'simple', 'maybe', 'military'], ['arms', 'possible', 'required', 'unit', 'makes'], ['militia', 'station', 'store', 'either', 'remark'], ['send', 'brought', 'system', 'believe', 'attack'], ['computer', 'radar', 'figure', 'countries', 'private'], ['follows', 'apartment', 'discussion', 'plane', 'inc'], ['absolute', 'right', 'note', 'request', 'large'], ['illegal', 'floor', 'april', 'latest', 'rs'], ['act', 'mean', 'areas', 'religious', 'saw'], ['safety', 'rg', 'length', 'trust', 'equipment'], ['faith', 'percent', 'died', 'existence', 'places'], ['bos', 'code', 'ways', 'thread', 'speed'], ['widget', 'gif', 'peter', 'scott', 'recommend'], ['table', 'risk', 'product', 'price', 'ibm'], ['rk', 'everything', 'training', 'saying', 'social'], ['live', 'month', 'local', 'spacecraft', 'attitude'], ['select', 'suspect', 'hot', 'turks', 'put'], ['length', 'son', 'noted', 'islamic', 'car'], ['asking', 'report', 'including', 'regular', 'plus'], ['perfect', 'usual', 'bh', 'job', 'trying'], ['jpeg', 'mx', 'write', 'impact', 'angeles'], ['star', 'forget', 'couple', 'lib', 'trying'], ['zd', 'activity', 'interesting', 'request', 'killed'], ['ie', 'reply', 'ever', 'soon', 'along'], ['yeah', 'ibm', 'decide', 'playing', 'statements'], ['sold', 'appreciate', 'suggest', 'description', 'anything'], ['montreal', 'upgrade', 'hold', 'lg', 'eat'], ['document', 'hundred', 'mike', 'nazis', 'speak'], ['sin', 'date', 'uunet', 'thread', 'hm'], ['seem', 'failed', 'may', 'court', 'said'], ['pin', 'parents', 'big', 'o ...

# %% [markdown]
# ## Batch Size 32 and learning rate 15

# %%
ctmb1 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                  dropout=0.2, batch_size=32, lr=15, solver='adam',
                  n_components=10, num_epochs=100)
ctmb2 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                  dropout=0.2, batch_size=32, lr=15, solver='adam',
                  n_components=20, num_epochs=100)
ctmb3 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                  dropout=0.2, batch_size=32, lr=15, solver='adam',
                  n_components=30, num_epochs=100)
ctmb4 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                  dropout=0.2, batch_size=32, lr=15, solver='adam',
                  n_components=50, num_epochs=100)
ctmb5 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                  dropout=0.2, batch_size=32, lr=15, solver='adam',
                  n_components=100, num_epochs=100)

# %%
ctmb1.fit(training_dataset1)
ctmb2.fit(training_dataset1) 
ctmb3.fit(training_dataset1)
ctmb4.fit(training_dataset1)
ctmb5.fit(training_dataset1)
# Out:
# Epoch: [100/100]	 Seen Samples: [1094400/1095100]	Train Loss: nan	Time: 0:00:11.503402: : 100it [18:33, 11.13s/it]
# Sampling: [20/20]: : 20it [01:20,  4.02s/it]
# Epoch: [100/100]	 Seen Samples: [1094400/1095100]	Train Loss: nan	Time: 0:00:10.919300: : 100it [18:54, 11.34s/it]
# Sampling: [20/20]: : 20it [01:31,  4.57s/it]
# Epoch: [100/100]	 Seen Samples: [1094400/1095100]	Train Loss: nan	Time: 0:00:12.381671: : 100it [19:12, 11.52s/it]
# Sampling: [20/20]: : 20it [01:35,  4.76s/it]
# Epoch: [100/100]	 Seen Samples: [1094400/1095100]	Train Loss: nan	Time: 0:00:12.031894: : 100it [18:53, 11.34s/it]
# Sampling: [20/20]: : 20it [01:42,  5.11s/it]
# Epoch: [100/100]	 Seen Samples: [1094400/1095100]	Train Loss: nan	Time: 0:00:13.074626: : 100it [20:46, 12.47s/it]
# Sampling: [20/20]: : 20it [01:47,  5.38s/it]

# %%
npmib1 = CoherenceNPMI(texts=texts, topics=ctmb1.get_topic_lists(10)); b1 = npmib1.score(topk=10)
npmib2 = CoherenceNPMI(texts=texts, topics=ctmb2.get_topic_lists(10)); b2 = npmib2.score(topk=10)
npmib3 = CoherenceNPMI(texts=texts, topics=ctmb3.get_topic_lists(10)); b3 = npmib3.score(topk=10)
npmib4 = CoherenceNPMI(texts=texts, topics=ctmb4.get_topic_lists(10)); b4 = npmib4.score(topk=10)
npmib5 = CoherenceNPMI(texts=texts, topics=ctmb5.get_topic_lists(10)); b5 = npmib5.score(topk=10)

# %%
print(f"for 10 topics, the coherenceNPMI is {b1}")
print(f"for 20 topics, the coherenceNPMI is {b2}")
print(f"for 30 topics, the coherenceNPMI is {b3}")
print(f"for 50 topics, the coherenceNPMI is {b4}")
print(f"for 100 topics, the coherenceNPMI is {b5}")
# Out:
# for 10 topics, the coherenceNPMI is 0.13694446572443153
# for 20 topics, the coherenceNPMI is -0.08294739701591167
# for 30 topics, the coherenceNPMI is 0.10902113721593902
# for 50 topics, the coherenceNPMI is 0.0264843100851418
# for 100 topics, the coherenceNPMI is 0.062197701543839135

# %%
tdb1 = TopicDiversity(topics=ctmb1.get_topic_lists(10)); tb1 = tdb1.score(topk=10)
tdb2 = TopicDiversity(topics=ctmb2.get_topic_lists(10)); tb2 = tdb2.score(topk=10)
tdb3 = TopicDiversity(topics=ctmb3.get_topic_lists(10)); tb3 = tdb3.score(topk=10)
tdb4 = TopicDiversity(topics=ctmb4.get_topic_lists(10)); tb4 = tdb4.score(topk=10)
tdb5 = TopicDiversity(topics=ctmb5.get_topic_lists(10)); tb5 = tdb5.score(topk=10)

# %%
print(f"for 10 topics, the TopicDiversity is {tb1}")
print(f"for 20 topics, the TopicDiversity is {tb2}")
print(f"for 30 topics, the TopicDiversity is {tb3}")
print(f"for 50 topics, the TopicDiversity is {tb4}")
print(f"for 100 topics, the TopicDiversity is {tb5}")
# Out:
# for 10 topics, the TopicDiversity is 0.9
# for 20 topics, the TopicDiversity is 0.585
# for 30 topics, the TopicDiversity is 0.7933333333333333
# for 50 topics, the TopicDiversity is 0.5
# for 100 topics, the TopicDiversity is 0.404

# %%
print(ctmb1.get_topic_lists(k=5))
print("////")
print(ctmb2.get_topic_lists(k=5))
print("////")
print(ctmb3.get_topic_lists(k=5))
print("////")
print(ctmb4.get_topic_lists(k=5))
print("////")
print(ctmb5.get_topic_lists(k=5))
# Out:
# [['team', 'year', 'game', 'nd', 'games'], ['mb', 'drive', 'fine', 'cable', 'card'], ['ax', 'mv', 'mw', 'cx', 'db'], ['md', 'ww', 'qs', 'sk', 'uw'], ['clipper', 'use', 'chip', 'would', 'encryption'], ['people', 'would', 'israeli', 'israel', 'president'], ['god', 'jesus', 'church', 'christian', 'believe'], ['file', 'edu', 'com', 'window', 'program'], ['giz', 'qax', 'bhj', 'max', 'ey'], ['people', 'would', 'gun', 'car', 'said']]
# ////
# [['shared', 'modified', 'sending', 'distributed', 'variety'], ['one', 'people', 'would', 'use', 'key'], ['merely', 'implementation', 'modified', 'applied', 'caught'], ['length', 'implementation', 'variety', 'ok', 'obtained'], ['drive', 'ax', 'would', 'think', 'god'], ['thanks', 'modified', 'responses', 'please', 'hello'], ['thanks', 'anyone', 'mb', 'please', 'hi'], ['thanks', 'accurate', 'applied', 'chicago', 'rangers'], ['people', 'god', 'would', 'church', 'bible'], ['gun', 'us', 'government', 'law', 'israel'], ['thanks', 'variety', 'packages', 'modified', 'appreciate'], ['modified', 'variety', 'responses', 'obtained', 'sending'], ['israel', 'jesus', 'wrong', 'people', 'islamic'], ['use', 'using', 'people', 'government', 'available'], ['team', 'game', 'games', 'hockey', 'players'], ['god', 'one', 'drive', 'would', 'problem'], ['thanks', 'windows', 'window', 'using', 'screen'], ['windows', 'using', 'thanks', 'running', 'screen'], ['thanks', 'sale', 'appreciated', 'modem', 'card'], ['st', 'modified', 'game', 'huge', 'remain']]
# ////
# [['qq', 'qax', 'posts', 'generation', 'yf'], ['grant', 'obtained', 'returned', 'qax', 'description'], ['screen', 'thanks', 'convert', 'application', 'resolution'], ['god', 'one', 'jesus', 'universe', 'would'], ['one', 'said', 'people', 'us', 'went'], ['turkish', 'armenian', 'greek', 'turks', 'turkey'], ['mb', 'scsi', 'drive', 'hard', 'card'], ['god', 'bible', 'jesus', 'faith', 'christians'], ['returned', 'structure', 'vote', 'obtained', 'collection'], ['giz', 'qax', 'bhj', 'qq', 'ey'], ['ripem', 'privacy', 'key', 'faq', 'security'], ['period', 'vs', 'pittsburgh', 'pit', 'det'], ['drive', 'mb', 'scsi', 'bus', 'hard'], ['ax', 'mv', 'mw', 'zd', 'wt'], ['space', 'launch', 'lunar', 'orbit', 'mission'], ['output', 'entry', 'file', 'build', 'rules'], ['israel', 'israeli', 'arab', 'land', 'jews'], ['water', 'moon', 'returned', 'project', 'food'], ['looking', 'sale', 'asking', 'model', 'lists'], ['chip', 'clipper', 'keys', 'encryption', 'key'], ['gun', 'firearms', 'guns', 'crime', 'militia'], ['stephanopoulos', 'president', 'mr', 'think', 'jobs'], ['md', 'ww', 'hz', 'qs', 'uw'], ['car', 'engine', 'cars', 'bike', 'road'], ['ax', 'di', 'max', 'um', 'tm'], ['edu', 'image', 'tar', 'version', 'motif'], ['nasa', 'also', 'space', 'shuttle', 'images'], ['db', 'sale', 'bh', 'shipping', 'condition'], ['game', 'team', 'players', 'year', 'season'], ['windows', 'window', 'problem', 'screen', 'widget']]
# ////
# [['game', 'team', 'games', 'year', 'players'], ['windows', 'drive', 'apple', 'thanks', 'using'], ['people', 'believe', 'armenian', 'think', 'christians'], ['god', 'would', 'one', 'people', 'think'], ['year', 'team', 'game', 'baseball', 'better'], ['people', 'god', 'would', 'religion', 'live'], ['looking', 'address', 'thanks', 'ftp', 'mail'], ['associated', 'colorado', 'aids', 'structure', 'closed'], ['windows', 'thanks', 'please', 'hi', 'files'], ['space', 'car', 'nasa', 'cars', 'engine'], ['anybody', 'lists', 'description', 'success', 'fi'], ['windows', 'problem', 'use', 'edu', 'system'], ['sale', 'price', 'looking', 'asking', 'interested'], ['god', 'one', 'jesus', 'christian', 'bible'], ['windows', 'drive', 'problem', 'scsi', 'window'], ['legitimate', 'develop', 'generation', 'grant', 'obtained'], ['gun', 'people', 'would', 'government', 'guns'], ['thanks', 'anyone', 'looking', 'anybody', 'advance'], ['space', 'would', 'one', 'people', 'firearms'], ['god', 'jesus', 'christian', 'christians', 'bible'], ['key', 'clipper', 'chip', 'keys', 'secure'], ['giz', 'qax', 'bxn', 'bhj', 'tm'], ['israel', 'israeli', 'jewish', 'arabs', 'jews'], ['existing', 'foundation', 'suggested', 'operations', 'document'], ['drive', 'mb', 'windows', 'apple', 'card'], ['israel', 'israeli', 'would', 'people', 'arab'], ['existing', 'established', 'named', 'described', 'papers'], ['window', 'display', 'application', 'widget', 'motif'], ['one', 'get', 'key', 'time', 'would'], ['drive', 'ax', 'scsi', 'ide', 'controller'], ['returned', 'grant', 'obtained', 'foundation', 'aids'], ['people', 'turkish', 'armenian', 'also', 'armenians'], ['problems', 'running', 'problem', 'car', 'anyone'], ['sale', 'shipping', 'please', 'offer', 'condition'], ['gun', 'law', 'israeli', 'guns', 'country'], ['gun', 'guns', 'chip', 'key', 'government'], ['present', 'grant', 'official', 'count', 'fair'], ['giz', 'poster', 'art', 'quoted', 'extremely'], ['jesus', 'bible', 'people', 'us', 'god'], ['god', 'people', 'one', 'would', 'jesus'], ['game', 'year', 'team', 'baseball', 'games'], ['colorado', 'figure', 'building', 'child', 'grant'], ['named', 'announced', 'collection', 'huge', 'foundation'], ['evidence', 'believe', 'agree', 'religion', 'israel'], ['thanks', 'sale', 'advance', 'ide', 'card'], ['team', 'game', 'season', 'rangers', 'teams'], ['year', 'car', 'game', 'better', 'hit'], ['one', 'would', 'god', 'people', 'also'], ['windows', 'problem', 'card', 'seems', 'ide'], ['one', 'space', 'use', 'system', 'used']]
# ////
# [['space', 'nasa', 'game', 'year', 'list'], ['one', 'people', 'like', 'would', 'even'], ['windows', 'thanks', 'code', 'files', 'package'], ['key', 'security', 'space', 'shuttle', 'please'], ['windows', 'card', 'board', 'memory', 'video'], ['god', 'christians', 'christian', 'church', 'christianity'], ['think', 'players', 'like', 'would', 'get'], ['board', 'card', 'bus', 'windows', 'mb'], ['sale', 'offer', 'interested', 'email', 'shipping'], ['sale', 'thanks', 'offer', 'brand', 'asking'], ['drive', 'card', 'controller', 'calgary', 'sale'], ['game', 'team', 'year', 'play', 'players'], ['scsi', 'drive', 'mb', 'bus', 'card'], ['year', 'team', 'game', 'players', 'player'], ['thanks', 'card', 'sale', 'drive', 'controller'], ['period', 'game', 'pittsburgh', 'calgary', 'scoring'], ['people', 'would', 'one', 'time', 'said'], ['god', 'jesus', 'one', 'church', 'life'], ['operation', 'journal', 'variety', 'reach', 'smaller'], ['israel', 'israeli', 'gas', 'fbi', 'law'], ['game', 'year', 'play', 'team', 'players'], ['church', 'god', 'cheers', 'much', 'heaven'], ['push', 'late', 'previous', 'suggested', 'japanese'], ['car', 'engine', 'get', 'ground', 'used'], ['windows', 'thanks', 'using', 'system', 'use'], ['imagine', 'break', 'paper', 'names', 'develop'], ['ex', 'yd', 'nrhj', 'bxn', 'di'], ['god', 'one', 'science', 'atheist', 'like'], ['people', 'think', 'president', 'would', 'game'], ['israel', 'jews', 'god', 'arab', 'israeli'], ['ax', 'game', 'team', 'leafs', 'scoring'], ['clipper', 'chip', 'keys', 'key', 'encryption'], ['gun', 'guns', 'government', 'police', 'state'], ['keys', 'encryption', 'clipper', 'public', 'secure'], ['giz', 'bhj', 'described', 'push', 'distributed'], ['israel', 'israeli', 'god', 'arab', 'jesus'], ['ax', 'card', 'thanks', 'windows', 'advance'], ['ww', 'uw', 'md', 'ck', 'qs'], ['please', 'sale', 'thanks', 'interested', 'windows'], ['windows', 'thanks', 'window', 'using', 'problem'], ['orbit', 'space', 'people', 'lunar', 'nasa'], ['director', 'foundation', 'postings', 'noted', 'nrhj'], ['car', 'engine', 'bike', 'speed', 'cars'], ['windows', 'window', 'running', 'screen', 'using'], ['car', 'space', 'engine', 'cars', 'bike'], ['window', 'default', 'running', 'application', 'lib'], ['plan', 'described', 'rule', 'success', 'poster'], ['armenian', 'armenians', 'israel', 'israeli', 'turks'], ['one', 'jesus', 'would', 'think', 'church'], ['looking', 'thanks', 'anyone', 'mail', 'please'], ['clipper', 'chip', 'escrow', 'encrypted', 'key'], ['qs', 'cx', 'ww', 'id', 'qy'], ['chip', 'clipper', 'key', 'keys', 'encryption'], ['mb', 'drive', 'apple', 'scsi', 'problem'], ['windows', 'mac', 'like', 'software', 'using'], ['space', 'nasa', 'gun', 'shuttle', 'moon'], ['israel', 'israeli', 'arab', 'gun', 'jews'], ['would', 'armenian', 'turks', 'greek', 'armenia'], ['government', 'nsa', 'clipper', 'encryption', 'chip'], ['people', 'think', 'like', 'would', 'one'], ['people', 'would', 'gun', 'government', 'guns'], ['anyone', 'looking', 'info', 'thanks', 'interested'], ['okz', 'nrhj', 'km', 'yf', 'fq'], ['chip', 'clipper', 'one', 'key', 'would'], ['thanks', 'looking', 'anyone', 'files', 'anybody'], ['site', 'summary', 'archive', 'standards', 'anybody'], ['water', 'gas', 'associated', 'fyn', 'imagine'], ['god', 'jesus', 'bible', 'christ', 'faith'], ['edu', 'also', 'space', 'lunar', 'ftp'], ['patients', 'food', 'msg', 'science', 'medical'], ['armenian', 'israel', 'armenians', 'israeli', 'gun'], ['israeli', 'time', 'greek', 'people', 'arabs'], ['thanks', 'space', 'please', 'advance', 'mail'], ['armenian', 'turks', 'armenians', 'turkish', 'genocide'], ['game', 'year', 'think', 'would', 'going'], ['file', 'windows', 'program', 'mv', 'output'], ['mb', 'drive', 'bus', 'scsi', 'disk'], ['space', 'car', 'lunar', 'launch', 'vehicle'], ['key', 'chip', 'mb', 'card', 'bit'], ['windows', 'use', 'like', 'software', 'one'], ['year', 'game', 'last', 'team', 'players'], ['god', 'widget', 'one', 'motif', 'window'], ['speech', 'passed', 'released', 'changing',  ...

# %% [markdown]
# ## Batch size 1024 and learning rate 1e-7

# %%
ctmc1 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                 dropout=0.2, batch_size=1024, lr=1e-7, solver='adam',
                 n_components=10, num_epochs=100)
ctmc2 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                 dropout=0.2, batch_size=1024, lr=1e-7, solver='adam',
                 n_components=20, num_epochs=100)
ctmc3 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                 dropout=0.2, batch_size=1024, lr=1e-7, solver='adam',
                 n_components=30, num_epochs=100)
ctmc4 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                 dropout=0.2, batch_size=1024, lr=1e-7, solver='adam',
                 n_components=50, num_epochs=100)
ctmc5 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                 dropout=0.2, batch_size=1024, lr=1e-7, solver='adam',
                 n_components=100, num_epochs=100)

# %%
ctmc1.fit(training_dataset1)
ctmc2.fit(training_dataset1)
ctmc3.fit(training_dataset1)
ctmc4.fit(training_dataset1)
ctmc5.fit(training_dataset1)
# Out:
# Epoch: [100/100]	 Seen Samples: [1024000/1095100]	Train Loss: 358410554.73821104	Time: 0:00:02.918322: : 100it [04:55,  2.95s/it]
# Sampling: [20/20]: : 20it [00:37,  1.87s/it]
# Epoch: [100/100]	 Seen Samples: [1024000/1095100]	Train Loss: 10729534703.688074	Time: 0:00:02.552770: : 100it [04:48,  2.88s/it]
# Sampling: [20/20]: : 20it [00:37,  1.90s/it]
# Epoch: [100/100]	 Seen Samples: [1024000/1095100]	Train Loss: 22782043896.925888	Time: 0:00:02.999342: : 100it [04:27,  2.67s/it]
# Sampling: [20/20]: : 20it [00:38,  1.93s/it]
# Epoch: [100/100]	 Seen Samples: [1024000/1095100]	Train Loss: 32449287987.266285	Time: 0:00:02.751385: : 100it [04:49,  2.89s/it]
# Sampling: [20/20]: : 20it [00:39,  1.95s/it]
# Epoch: [100/100]	 Seen Samples: [1024000/1095100]	Train Loss: 39046484944.59589	Time: 0:00:02.786825: : 100it [05:03,  3.03s/it]
# Sampling: [20/20]: : 20it [00:42,  2.12s/it]

# %%
npmic1 = CoherenceNPMI(texts=texts, topics=ctmc1.get_topic_lists(10)); c1 = npmic1.score(topk=10)
npmic2 = CoherenceNPMI(texts=texts, topics=ctmc2.get_topic_lists(10)); c2 = npmic2.score(topk=10)
npmic3 = CoherenceNPMI(texts=texts, topics=ctmc3.get_topic_lists(10)); c3 = npmic3.score(topk=10)
npmic4 = CoherenceNPMI(texts=texts, topics=ctmc4.get_topic_lists(10)); c4 = npmic4.score(topk=10)
npmic5 = CoherenceNPMI(texts=texts, topics=ctmc5.get_topic_lists(10)); c5 = npmic5.score(topk=10)

# %%
print(f"for 10 topics, the coherenceNPMI is {c1}")
print(f"for 20 topics, the coherenceNPMI is {c2}")
print(f"for 30 topics, the coherenceNPMI is {c3}")
print(f"for 50 topics, the coherenceNPMI is {c4}")
print(f"for 100 topics, the coherenceNPMI is {c5}")
# Out:
# for 10 topics, the coherenceNPMI is -0.23494672797729726
# for 20 topics, the coherenceNPMI is -0.2590431524098522
# for 30 topics, the coherenceNPMI is -0.24916408423010594
# for 50 topics, the coherenceNPMI is -0.2569681246550537
# for 100 topics, the coherenceNPMI is -0.2621705790517895

# %%
tdc1 = TopicDiversity(topics=ctmc1.get_topic_lists(10)); tc1 = tdc1.score(topk=10)
tdc2 = TopicDiversity(topics=ctmc2.get_topic_lists(10)); tc2 = tdc2.score(topk=10)
tdc3 = TopicDiversity(topics=ctmc3.get_topic_lists(10)); tc3 = tdc3.score(topk=10)
tdc4 = TopicDiversity(topics=ctmc4.get_topic_lists(10)); tc4 = tdc4.score(topk=10)
tdc5 = TopicDiversity(topics=ctmc5.get_topic_lists(10)); tc5 = tdc5.score(topk=10)

# %%
print(f"for 10 topics, the TopicDiversity is {tc1}")
print(f"for 20 topics, the TopicDiversity is {tc2}")
print(f"for 30 topics, the TopicDiversity is {tc3}")
print(f"for 50 topics, the TopicDiversity is {tc4}")
print(f"for 100 topics, the TopicDiversity is {tc5}")
# Out:
# for 10 topics, the TopicDiversity is 0.98
# for 20 topics, the TopicDiversity is 0.935
# for 30 topics, the TopicDiversity is 0.94
# for 50 topics, the TopicDiversity is 0.906
# for 100 topics, the TopicDiversity is 0.792

# %%
print(ctmc1.get_topic_lists(k=5))
print("////")
print(ctmc2.get_topic_lists(k=5))
print("////")
print(ctmc3.get_topic_lists(k=5))
print("////")
print(ctmc4.get_topic_lists(k=5))
print("////")
print(ctmc5.get_topic_lists(k=5))
# Out:
# [['later', 'sk', 'double', 'final', 'new'], ['apartment', 'enter', 'process', 'end', 'genocide'], ['model', 'alive', 'port', 'alternative', 'written'], ['cost', 'trade', 'treatment', 'start', 'japanese'], ['decide', 'sale', 'sgi', 'features', 'early'], ['encrypted', 'george', 'normally', 'facts', 'mm'], ['dx', 'reasonable', 'pgp', 'status', 'across'], ['clients', 'bs', 'normal', 'defense', 'coming'], ['stated', 'id', 'field', 'realize', 'start'], ['mode', 'concept', 'differences', 'message', 'quickly']]
# ////
# [['pointed', 'change', 'half', 'felt', 'pitt'], ['input', 'live', 'experience', 'com', 'eq'], ['support', 'rule', 'wrote', 'kind', 'meant'], ['pretty', 'simms', 'kept', 'drivers', 'letter'], ['intended', 'ide', 'rom', 'game', 'internal'], ['apr', 'alive', 'compatible', 'article', 'purpose'], ['yd', 'science', 'certainly', 'sin', 'kn'], ['ripem', 'mentioned', 'group', 'everybody', 'software'], ['mentioned', 'heard', 'rl', 'deleted', 'went'], ['citizens', 'library', 'standards', 'wrong', 'systems'], ['admit', 'moral', 'kind', 'medicine', 'network'], ['select', 'text', 'ready', 'certainly', 'rsa'], ['obtained', 'friend', 'rom', 'colorado', 'rlk'], ['kn', 'body', 'christians', 'dave', 'interesting'], ['manager', 'rom', 'true', 'sold', 'crime'], ['please', 'press', 'gas', 'mov', 'pitt'], ['name', 'twice', 'poster', 'telling', 'azerbaijani'], ['mother', 'meet', 'professor', 'ability', 'steve'], ['plane', 'lunar', 'essentially', 'shot', 'avoid'], ['prevent', 'lcs', 'bus', 'well', 'russian']]
# ////
# [['commercial', 'anyone', 'character', 'berkeley', 'usual'], ['install', 'various', 'mind', 'yes', 'modem'], ['excuse', 'baseball', 'far', 'law', 'sure'], ['required', 'easy', 'spent', 'suspect', 'radio'], ['expected', 'values', 'pt', 'says', 'administration'], ['receive', 'editor', 'la', 'driving', 'sufficient'], ['setup', 'earth', 'significant', 'volume', 'library'], ['company', 'thread', 'least', 'domain', 'traffic'], ['monitor', 'orbit', 'issue', 'red', 'lost'], ['tax', 'scx', 'side', 'month', 'starts'], ['sale', 'forget', 'exact', 'misc', 'francisco'], ['countries', 'interested', 'char', 'really', 'oil'], ['takes', 'credit', 'windows', 'quality', 'still'], ['red', 'packages', 'ex', 'european', 'game'], ['larger', 'uses', 'video', 'blood', 'use'], ['valid', 'disease', 'return', 'willing', 'km'], ['along', 'scripture', 'lead', 'door', 'morning'], ['important', 'ey', 'wife', 'interface', 'annual'], ['senate', 'central', 'story', 'pull', 'earlier'], ['cars', 'rangers', 'solid', 'radio', 'woman'], ['errors', 'memory', 'answers', 'guide', 'question'], ['drug', 'come', 'stupid', 'chris', 'jose'], ['lack', 'away', 'false', 'call', 'years'], ['people', 'woman', 'talk', 'pressure', 'lock'], ['statement', 'words', 'reason', 'community', 'francisco'], ['space', 'car', 'committee', 'shall', 'levels'], ['half', 'eff', 'politics', 'index', 'yf'], ['language', 'thread', 'note', 'vga', 'philadelphia'], ['become', 'routines', 'heaven', 'fall', 'message'], ['gas', 'currently', 'response', 'errors', 'nature']]
# ////
# [['forward', 'immediately', 'wish', 'guess', 'series'], ['window', 'press', 'waiting', 'news', 'costs'], ['ride', 'variety', 'two', 'industry', 'total'], ['check', 'secretary', 'lock', 'performance', 'community'], ['resources', 'proper', 'speech', 'scoring', 'united'], ['constitution', 'conflict', 'select', 'upgrade', 'users'], ['jpeg', 'internet', 'value', 'attack', 'directory'], ['allows', 'project', 'lg', 'sound', 'dc'], ['plus', 'angeles', 'keys', 'document', 'paul'], ['tom', 'easy', 'steve', 'scale', 'appear'], ['perhaps', 'client', 'luck', 'front', 'latest'], ['role', 'stream', 'cal', 'conditions', 'israeli'], ['chips', 'either', 'xv', 'chicago', 'normal'], ['applications', 'however', 'designed', 'mark', 'msg'], ['case', 'certain', 'follow', 'civilians', 'digital'], ['somehow', 'members', 'title', 'created', 'getting'], ['worse', 'message', 'document', 'towards', 'generation'], ['developed', 'changing', 'lack', 'future', 'microsoft'], ['associated', 'riding', 'islam', 'track', 'bay'], ['rs', 'disk', 'court', 'clock', 'father'], ['machine', 'device', 'month', 'richard', 'rec'], ['forward', 'women', 'country', 'serious', 'jim'], ['recently', 'certain', 'document', 'cd', 'agents'], ['remember', 'service', 'language', 'math', 'satellite'], ['vw', 'encryption', 'accurate', 'noticed', 'organization'], ['enough', 'got', 'obtain', 'still', 'takes'], ['depending', 'direction', 'body', 'nation', 'position'], ['prove', 'bits', 'dod', 'york', 'number'], ['leave', 'ftp', 'separate', 'money', 'players'], ['cpu', 'bad', 'equipment', 'fairly', 'larger'], ['qq', 'america', 'banks', 'sea', 'thomas'], ['person', 'power', 'environment', 'gay', 'history'], ['providing', 'added', 'cannot', 'fall', 'ne'], ['described', 'purpose', 'ho', 'traffic', 'simple'], ['guy', 'developed', 'editor', 'boston', 'two'], ['lock', 'sales', 'month', 'beginning', 'un'], ['strong', 'drive', 'engine', 'talking', 'nl'], ['call', 'blue', 'kb', 'alt', 'funds'], ['obtained', 'training', 'push', 'commercial', 'caused'], ['smaller', 'anonymous', 'capable', 'somewhat', 'everything'], ['home', 'sumgait', 'answer', 'comment', 'woman'], ['shows', 'obviously', 'giving', 'morning', 'easier'], ['although', 'solid', 'fall', 'btw', 'hurt'], ['variety', 'definitely', 'like', 'league', 'mi'], ['goals', 'wants', 'everybody', 'trouble', 'front'], ['ever', 'places', 'max', 'bob', 'right'], ['st', 'disk', 'jews', 'moon', 'show'], ['saw', 'ibm', 'tom', 'flames', 'statements'], ['air', 'acts', 'bytes', 'comments', 'hand'], ['cancer', 'air', 'dead', 'imagine', 'city']]
# ////
# [['dc', 'address', 'seen', 'ax', 'civil'], ['los', 'ed', 'activities', 'avoid', 'session'], ['lg', 'interface', 'tells', 'felt', 'well'], ['tests', 'anyway', 'mp', 'tq', 'vancouver'], ['file', 'upon', 'deleted', 'among', 'years'], ['idea', 'sale', 'rg', 'eric', 'fire'], ['lie', 'fq', 'forget', 'nasa', 'efforts'], ['map', 'administration', 'star', 'copies', 'properly'], ['family', 'record', 'strong', 'natural', 'kings'], ['correct', 'enough', 'facts', 'far', 'slave'], ['thousands', 'degree', 'mass', 'sq', 'believe'], ['sent', 'child', 'problems', 'purchase', 'banks'], ['owners', 'department', 'mb', 'fuel', 'concept'], ['xt', 'claimed', 'happened', 'happens', 'entire'], ['get', 'problems', 'entirely', 'illegal', 'happy'], ['msg', 'soviet', 'david', 'fall', 'welcome'], ['attack', 'immediately', 'season', 'hand', 'use'], ['deleted', 'object', 'apartment', 'agents', 'vw'], ['shows', 'members', 'thank', 'media', 'part'], ['notice', 'missed', 'replace', 'imagine', 'word'], ['players', 'value', 'wm', 'brand', 'congress'], ['range', 'list', 'objective', 'came', 'ten'], ['community', 'hurt', 'sk', 'cal', 'points'], ['printf', 'necessary', 'cannot', 'george', 'yeah'], ['prior', 'commercial', 'stephanopoulos', 'truly', 'se'], ['spacecraft', 'areas', 'san', 'obviously', 'change'], ['god', 'toward', 'neutral', 'europe', 'dc'], ['edge', 'document', 'stuff', 'char', 'rather'], ['circuit', 'test', 'eventually', 'cities', 'conference'], ['average', 'led', 'hurt', 'according', 'warning'], ['line', 'basis', 'troops', 'specific', 'ac'], ['tell', 'deal', 'sources', 'detroit', 'resources'], ['offer', 'two', 'channel', 'remain', 'april'], ['well', 'longer', 'dollars', 'monitor', 'college'], ['anyway', 'efforts', 'published', 'realize', 'done'], ['copy', 'work', 'report', 'without', 'sometimes'], ['development', 'behavior', 'weak', 'weapons', 'hp'], ['lists', 'related', 'dollars', 'sq', 'thus'], ['realize', 'period', 'afraid', 'speed', 'slightly'], ['ri', 'obviously', 'path', 'instead', 'modified'], ['thing', 'math', 'sense', 'accept', 'else'], ['coming', 'expansion', 'international', 'ray', 'refer'], ['scsi', 'environment', 'whether', 'meaning', 'historical'], ['everybody', 'newsgroups', 'accepted', 'free', 'difficult'], ['clearly', 'problems', 'movement', 'senate', 'rather'], ['thought', 'ripem', 'exist', 'models', 'request'], ['leafs', 'qy', 'since', 'everything', 'visual'], ['apple', 'um', 'vehicle', 'thomas', 'faith'], ['average', 'random', 'character', 'larger', 'id'], ['training', 'little', 'separate', 'western', 'installed'], ['frank', 'via', 'heaven', 'calling', 'applied'], ['increased', 'civil', 'oh', 'provides', 'draft'], ['hours', 'bios', 'weight', 'method', 'refer'], ['des', 'clipper', 'religions', 'whole', 'id'], ['models', 'remember', 'arabs', 'criminal', 'book'], ['radio', 'issue', 'fast', 'assume', 'opinion'], ['necessary', 'guide', 'wanted', 'se', 'present'], ['accepted', 'changes', 'police', 'tq', 'installed'], ['gc', 'widgets', 'woman', 'responsibility', 'shots'], ['started', 'hm', 'thread', 'newsgroups', 'civil'], ['safety', 'months', 'notice', 'technology', 'indeed'], ['bike', 'receive', 'attitude', 'please', 'anywhere'], ['ide', 'aids', 'um', 'tm', 'causes'], ['gay', 'father', 'forces', 'resolution', 'followed'], ['search', 'conclusion', 'evidence', 'feel', 'assume'], ['saved', 'random', 'assault', 'told', 'friend'], ['attempt', 'oname', 'last', 'works', 'manual'], ['park', 'reply', 'rec', 'decision', 'ne'], ['see', 'used', 'israel', 'view', 'special'], ['box', 'ram', 'loss', 'easily', 'read'], ['turks', 'allow', 'aware', 'fear', 'ed'], ['yd', 'scheme', 'ut', 'contain', 'race'], ['yesterday', 'shots', 'east', 'written', 'set'], ['drug', 'beyond', 'division', 'flames', 'matthew'], ['war', 'based', 'administration', 'june', 'dollars'], ['mk', 'drive', 'references', 'eg', 'million'], ['analysis', 'thank', 'happen', 'set', 'player'], ['button', 'philadelphia', 'external', 'effects', 'remote'], ['rule', 'comments', 'agency', 'fax', ' ...

# %% [markdown]
# ## Batch size 1024 and learning rate 15

# %%
ctmd1 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                 dropout=0.2, batch_size=1024, lr=15, solver='adam',
                 n_components=10, num_epochs=100)
ctmd2 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                 dropout=0.2, batch_size=1024, lr=15, solver='adam',
                 n_components=20, num_epochs=100)
ctmd3 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                 dropout=0.2, batch_size=1024, lr=15, solver='adam',
                 n_components=30, num_epochs=100)
ctmd4 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                 dropout=0.2, batch_size=1024, lr=15, solver='adam',
                 n_components=50, num_epochs=100)
ctmd5 = CombinedTM(bow_size=len(tpa.vocab), contextual_size=768, model_type='prodLDA',
                 dropout=0.2, batch_size=1024, lr=15, solver='adam',
                 n_components=100, num_epochs=100)

# %%
ctmd1.fit(training_dataset1)
ctmd2.fit(training_dataset1)
ctmd3.fit(training_dataset1)
ctmd4.fit(training_dataset1)
ctmd5.fit(training_dataset1)
# Out:
# Epoch: [100/100]	 Seen Samples: [1024000/1095100]	Train Loss: 539.4370819091797	Time: 0:00:02.948394: : 100it [04:46,  2.86s/it]
# Sampling: [20/20]: : 20it [00:38,  1.93s/it]
# Epoch: [100/100]	 Seen Samples: [1024000/1095100]	Train Loss: 557.857666015625	Time: 0:00:02.272464: : 100it [04:41,  2.82s/it]
# Sampling: [20/20]: : 20it [00:34,  1.71s/it]
# Epoch: [100/100]	 Seen Samples: [1024000/1095100]	Train Loss: 530.77490234375	Time: 0:00:02.985612: : 100it [04:55,  2.96s/it]
# Sampling: [20/20]: : 20it [00:41,  2.06s/it]
# Epoch: [100/100]	 Seen Samples: [1024000/1095100]	Train Loss: 593.3708618164062	Time: 0:00:02.974825: : 100it [04:57,  2.98s/it]
# Sampling: [20/20]: : 20it [00:41,  2.07s/it]
# Epoch: [100/100]	 Seen Samples: [1024000/1095100]	Train Loss: 822.5695251464844	Time: 0:00:02.920138: : 100it [05:08,  3.09s/it]
# Sampling: [20/20]: : 20it [00:46,  2.34s/it]

# %%
npmid1 = CoherenceNPMI(texts=texts, topics=ctmd1.get_topic_lists(10)); d1 = npmid1.score(topk=10)
npmid2 = CoherenceNPMI(texts=texts, topics=ctmd2.get_topic_lists(10)); d2 = npmid2.score(topk=10)
npmid3 = CoherenceNPMI(texts=texts, topics=ctmd3.get_topic_lists(10)); d3 = npmid3.score(topk=10)
npmid4 = CoherenceNPMI(texts=texts, topics=ctmd4.get_topic_lists(10)); d4 = npmid4.score(topk=10)
npmid5 = CoherenceNPMI(texts=texts, topics=ctmd5.get_topic_lists(10)); d5 = npmid5.score(topk=10)

# %%
print(f"for 10 topics, the coherenceNPMI is {d1}")
print(f"for 20 topics, the coherenceNPMI is {d2}")
print(f"for 30 topics, the coherenceNPMI is {d3}")
print(f"for 50 topics, the coherenceNPMI is {d4}")
print(f"for 100 topics, the coherenceNPMI is {d5}")
# Out:
# for 10 topics, the coherenceNPMI is -0.12208717555784236
# for 20 topics, the coherenceNPMI is -0.17089890763678858
# for 30 topics, the coherenceNPMI is -0.11367217633630475
# for 50 topics, the coherenceNPMI is -0.087623773175991
# for 100 topics, the coherenceNPMI is -0.14701510828828013

# %%
tdd1 = TopicDiversity(topics=ctmd1.get_topic_lists(10)); td1 = tdd1.score(topk=10)
tdd2 = TopicDiversity(topics=ctmd2.get_topic_lists(10)); td2 = tdd2.score(topk=10)
tdd3 = TopicDiversity(topics=ctmd3.get_topic_lists(10)); td3 = tdd3.score(topk=10)
tdd4 = TopicDiversity(topics=ctmd4.get_topic_lists(10)); td4 = tdd4.score(topk=10)
tdd5 = TopicDiversity(topics=ctmd5.get_topic_lists(10)); td5 = tdd5.score(topk=10)

# %%
print(f"for 10 topics, the TopicDiversity is {td1}")
print(f"for 20 topics, the TopicDiversity is {td2}")
print(f"for 30 topics, the TopicDiversity is {td3}")
print(f"for 50 topics, the TopicDiversity is {td4}")
print(f"for 100 topics, the TopicDiversity is {td5}")
# Out:
# for 10 topics, the TopicDiversity is 0.75
# for 20 topics, the TopicDiversity is 0.73
# for 30 topics, the TopicDiversity is 0.7066666666666667
# for 50 topics, the TopicDiversity is 0.598
# for 100 topics, the TopicDiversity is 0.497

# %%
print(ctmd1.get_topic_lists(k=5))
print("////")
print(ctmd2.get_topic_lists(k=5))
print("////")
print(ctmd3.get_topic_lists(k=5))
print("////")
print(ctmd4.get_topic_lists(k=5))
print("////")
print(ctmd5.get_topic_lists(k=5))
# Out:
# [['ice', 'mary', 'rangers', 'year', 'minnesota'], ['detroit', 'york', 'conference', 'wings', 'minor'], ['player', 'subject', 'committee', 'van', 'minnesota'], ['ax', 'max', 'pl', 'ei', 'ey'], ['play', 'year', 'boston', 'det', 'cs'], ['tor', 'buf', 'mary', 'wings', 'chi'], ['pittsburgh', 'cal', 'expansion', 'green', 'mon'], ['expansion', 'obtained', 'la', 'wings', 'flames'], ['final', 'york', 'hall', 'season', 'address'], ['detroit', 'season', 'cup', 'players', 'mary']]
# ////
# [['card', 'drives', 'disk', 'problem', 'twice'], ['mind', 'ie', 'space', 'far', 'traffic'], ['max', 'love', 'bh', 'resources', 'somewhere'], ['living', 'paul', 'black', 'pittsburgh', 'somewhere'], ['max', 'including', 'soviet', 'modem', 'technology'], ['whether', 'death', 'fire', 'robert', 'innocent'], ['technology', 'historical', 'stephanopoulos', 'jobs', 'comments'], ['push', 'living', 'last', 'carry', 'japanese'], ['lack', 'card', 'death', 'nl', 'drives'], ['order', 'source', 'tar', 'version', 'sources'], ['reasons', 'black', 'action', 'effective', 'alt'], ['ax', 'giz', 'fp', 'ql', 'tg'], ['card', 'drives', 'db', 'dr', 'os'], ['cx', 'stephanopoulos', 'ftp', 'formats', 'mail'], ['innocent', 'baseball', 'effects', 'calling', 'keep'], ['laws', 'paul', 'meet', 'likely', 'effects'], ['ql', 'sl', 'okz', 'nrhj', 'fij'], ['ibm', 'strong', 'black', 'contact', 'soviet'], ['reason', 'death', 'tl', 'rm', 'york'], ['pl', 'action', 'including', 'air', 'sx']]
# ////
# [['yes', 'mean', 'players', 'gun', 'goal'], ['dos', 'currently', 'domain', 'pixel', 'info'], ['armenians', 'us', 'said', 'state', 'see'], ['show', 'god', 'think', 'say', 'killed'], ['ey', 'ax', 'giz', 'ml', 'mr'], ['may', 'part', 'like', 'time', 'image'], ['believe', 'players', 'agree', 'period', 'really'], ['time', 'every', 'wire', 'problem', 'mind'], ['arabs', 'league', 'baseball', 'ahead', 'assume'], ['ahead', 'install', 'motherboard', 'title', 'count'], ['late', 'nhl', 'goal', 'wings', 'willing'], ['christian', 'league', 'baseball', 'another', 'yes'], ['greater', 'devices', 'title', 'passed', 'leads'], ['rsa', 'lib', 'build', 'mac', 'bike'], ['motherboard', 'fi', 'need', 'screen', 'install'], ['point', 'faith', 'season', 'make', 'life'], ['star', 'app', 'math', 'types', 'previous'], ['ey', 'giz', 'ax', 'cx', 'ck'], ['christian', 'app', 'mean', 'season', 'christians'], ['show', 'since', 'community', 'nhl', 'children'], ['card', 'app', 'machines', 'monitor', 'screen'], ['normally', 'excellent', 'equipment', 'bus', 'nec'], ['season', 'arabs', 'role', 'path', 'goal'], ['monitor', 'companies', 'status', 'modem', 'db'], ['teams', 'nhl', 'passed', 'anyway', 'pit'], ['types', 'msg', 'vga', 'asking', 'cable'], ['think', 'people', 'every', 'since', 'president'], ['make', 'said', 'turkish', 'something', 'going'], ['app', 'problem', 'machines', 'distribution', 'isa'], ['app', 'path', 'crime', 'heard', 'banks']]
# ////
# [['institute', 'message', 'chi', 'flight', 'edu'], ['english', 'noise', 'changes', 'weight', 'club'], ['users', 'nasa', 'widget', 'domain', 'functions'], ['offer', 'remain', 'computer', 'pages', 'produced'], ['people', 'see', 'way', 'well', 'really'], ['believe', 'point', 'going', 'israel', 'time'], ['going', 'point', 'could', 'many', 'never'], ['saying', 'believe', 'away', 'shot', 'three'], ['motherboard', 'pages', 'uses', 'need', 'anywhere'], ['well', 'government', 'see', 'key', 'like'], ['serial', 'helps', 'floor', 'manual', 'board'], ['offer', 'bob', 'lcs', 'judge', 'motherboard'], ['respond', 'disks', 'normally', 'uunet', 'index'], ['lcs', 'cd', 'modem', 'client', 'clients'], ['remain', 'brand', 'latest', 'rs', 'computer'], ['israel', 'point', 'god', 'said', 'going'], ['made', 'going', 'think', 'point', 'today'], ['state', 'like', 'going', 'one', 'away'], ['public', 'back', 'show', 'groups', 'nothing'], ['chip', 'latest', 'sgi', 'mouse', 'tool'], ['serial', 'parallel', 'sgi', 'supply', 'anyone'], ['said', 'christians', 'reason', 'gun', 'israel'], ['information', 'nasa', 'list', 'gov', 'ny'], ['offer', 'buffer', 'looking', 'seeing', 'english'], ['space', 'nasa', 'law', 'field', 'ever'], ['owner', 'followed', 'offer', 'yeah', 'regards'], ['dealer', 'brand', 'box', 'inside', 'carried'], ['address', 'via', 'zip', 'latest', 'seconds'], ['made', 'god', 'year', 'laws', 'take'], ['god', 'could', 'government', 'day', 'law'], ['system', 'need', 'test', 'posted', 'dod'], ['israel', 'going', 'people', 'saying', 'right'], ['computer', 'files', 'anywhere', 'looking', 'mov'], ['board', 'lcs', 'anybody', 'rs', 'remain'], ['ax', 'fq', 'lj', 'qq', 'qax'], ['christians', 'god', 'might', 'see', 'believe'], ['wm', 'cx', 'giz', 'zd', 'bhj'], ['scott', 'advance', 'disks', 'simms', 'buying'], ['request', 'domain', 'blue', 'library', 'include'], ['need', 'index', 'bbs', 'disks', 'released'], ['believe', 'away', 'talk', 'things', 'point'], ['people', 'saying', 'armenians', 'either', 'fact'], ['motorcycle', 'shell', 'complete', 'flight', 'radar'], ['believe', 'would', 'said', 'god', 'us'], ['stop', 'study', 'situation', 'fact', 'security'], ['believe', 'stephanopoulos', 'part', 'war', 'happened'], ['would', 'government', 'money', 'therefore', 'public'], ['brand', 'changes', 'okay', 'waiting', 'external'], ['point', 'part', 'course', 'agree', 'even'], ['seem', 'york', 'thing', 'clinton', 'post']]
# ////
# [['dx', 'sources', 'problems', 'wire', 'design'], ['section', 'des', 'ne', 'mo', 'keyboard'], ['one', 'stephanopoulos', 'armenian', 'armenians', 'internal'], ['sun', 'laws', 'inc', 'lived', 'according'], ['sun', 'allow', 'brian', 'opinion', 'system'], ['hi', 'lc', 'looking', 'yx', 'ql'], ['society', 'working', 'idea', 'money', 'freedom'], ['support', 'power', 'rocket', 'earth', 'mass'], ['entry', 'encryption', 'privacy', 'one', 'gif'], ['experience', 'contrib', 'tar', 'distribution', 'export'], ['one', 'encryption', 'cx', 'people', 'armenian'], ['look', 'lived', 'unix', 'guess', 'based'], ['day', 'least', 'group', 'forces', 'shipping'], ['pgp', 'berkeley', 'giving', 'motif', 'beginning'], ['part', 'saw', 'available', 'armenians', 'printf'], ['question', 'guy', 'market', 'translation', 'case'], ['work', 'crime', 'freedom', 'yet', 'clients'], ['later', 'tools', 'thanks', 'map', 'nasa'], ['postscript', 'hp', 'getting', 'laws', 'lcs'], ['drivers', 'issue', 'choice', 'motif', 'mean'], ['ql', 'configuration', 'mhz', 'ne', 'hm'], ['privacy', 'list', 'internet', 'apartment', 'use'], ['privacy', 'foundation', 'digital', 'eff', 'grant'], ['encryption', 'systems', 'israel', 'many', 'st'], ['laws', 'dec', 'brian', 'lived', 'tools'], ['list', 'anonymous', 'stephanopoulos', 'privacy', 'government'], ['db', 'list', 'would', 'encryption', 'get'], ['white', 'claim', 'crime', 'peter', 'mit'], ['work', 'might', 'claim', 'criminals', 'sales'], ['mov', 'government', 'byte', 'encryption', 'push'], ['part', 'privacy', 'would', 'op', 'like'], ['five', 'escrow', 'motif', 'postscript', 'ck'], ['editor', 'expensive', 'fbi', 'europe', 'turkey'], ['latest', 'cache', 'cable', 'jesus', 'experience'], ['image', 'encryption', 'use', 'program', 'armenian'], ['looking', 'cpu', 'one', 'host', 'use'], ['color', 'contrib', 'killing', 'cache', 'widget'], ['ql', 'hm', 'um', 'fij', 'pt'], ['mit', 'fix', 'ram', 'stuff', 'guys'], ['berkeley', 'directly', 'problems', 'false', 'cut'], ['willing', 'selling', 'ra', 'especially', 'kb'], ['government', 'line', 'already', 'stephanopoulos', 'encryption'], ['file', 'use', 'available', 'armenian', 'server'], ['export', 'contrib', 'postscript', 'person', 'side'], ['government', 'entry', 'one', 'encryption', 'available'], ['experience', 'brian', 'hundred', 'cache', 'giving'], ['person', 'contrib', 'fix', 'work', 'beginning'], ['entry', 'section', 'file', 'program', 'anonymous'], ['escrow', 'widgets', 'sources', 'buying', 'distribution'], ['support', 'according', 'majority', 'seriously', 'low'], ['encryption', 'cryptography', 'stephanopoulos', 'ra', 'handle'], ['section', 'kb', 'hear', 'program', 'supply'], ['release', 'away', 'known', 'larger', 'talking'], ['one', 'people', 'apartment', 'spot', 'like'], ['privacy', 'buf', 'pt', 'resource', 'especially'], ['armenians', 'fault', 'south', 'entry', 'school'], ['encryption', 'one', 'privacy', 'address', 'pt'], ['brian', 'hundred', 'include', 'installed', 'clients'], ['condition', 'talking', 'goal', 'money', 'wide'], ['modes', 'directly', 'uunet', 'killing', 'went'], ['hp', 'sort', 'several', 'knowledge', 'rs'], ['scx', 'sc', 'sp', 'si', 'weapon'], ['police', 'think', 'sale', 'clients', 'times'], ['based', 'put', 'selling', 'country', 'israeli'], ['available', 'pt', 'encryption', 'printf', 'selling'], ['isa', 'sound', 'tape', 'support', 'dod'], ['db', 'willing', 'sound', 'si', 'dx'], ['one', 'government', 'encryption', 'armenians', 'st'], ['encryption', 'available', 'one', 'make', 'entry'], ['list', 'part', 'reasons', 'another', 'ftp'], ['berkeley', 'laws', 'seriously', 'standard', 'ram'], ['dx', 'christian', 'needs', 'share', 'et'], ['willing', 'dx', 'cache', 'towards', 'purpose'], ['version', 'response', 'modem', 'aware', 'port'], ['see', 'causes', 'opinion', 'monitor', 'article'], ['government', 'program', 'available', 'encryption', 'use'], ['encryption', 'gif', 'us', 'privacy', 'anonymous'], ['someone', 'bad', 'standard', 'causes', 'access'], ['hp', 'problem', 'life', 'selling', 'wi ...

# %% [markdown]
# ### Out of this 4 combinations, the last combination of high learning rate and large batch size gives us topics with much lesser coherence and much less topic diversity. So, we can conclude that we have somewhat achived posterior collapse because in posterior collapse as the latent structure is not learned during training it gives us topics which are more or less similar i.e not diverse.

# %% [markdown]
# ## Posterior Collapse Condition:
# 1. High Learning Rate
# 2. Large Batch Size
