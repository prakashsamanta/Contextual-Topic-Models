# %%
import pandas as pd

# %%
dict1 = {'Number of Topics' : [10, 20, 30, 50, 100], 
         'all-mpnet-base-v2' : [0.156, 0.109, 0.113, 0.067, 0.066], 
         'stsb-roberta-large' : [0.162, 0.09, 0.08, 0.106, 0.100],
        'bert-based-nli-mean-tokens' : [0.169, 0.170, 0.099, 0.100, 0.094],
        'all-distilroberta-v1' : [0.122, 0.103, 0.143, 0.093, 0.070],
        'all-miniLM-L6-v2' : [0.159, 0.108, 0.099, 0.062, 0.074]}
df1 = pd.DataFrame(dict1); df1
# Out:
#    Number of Topics  all-mpnet-base-v2  stsb-roberta-large  \
# 0                10              0.156               0.162
# 1                20              0.109               0.090
# 2                30              0.113               0.080
# 3                50              0.067               0.106
# 4               100              0.066               0.100
#
#    bert-based-nli-mean-tokens  all-distilroberta-v1  all-miniLM-L6-v2
# 0                       0.169                 0.122             0.159
# 1                       0.170                 0.103             0.108
# 2                       0.099                 0.143             0.099
# 3                       0.100                 0.093             0.062
# 4                       0.094                 0.070             0.074

# %%
df1.to_csv('coherence.csv')

# %%
dict2 = {'Number of Topics' : [10, 20, 30, 50, 100], 
         'all-mpnet-base-v2' : [0.96, 0.83, 0.865, 0.690, 0.585], 
         'stsb-roberta-large' : [0.90, 0.84, 0.853, 0.632, 0.547],
        'bert-based-nli-mean-tokens' : [0.93, 0.86, 0.876, 0.688, 0.525],
        'all-distilroberta-v1' : [0.92, 0.87, 0.806, 0.72, 0.548],
        'all-miniLM-L6-v2' : [0.88, 0.92, 0.82, 0.73, 0.56]}
df2 = pd.DataFrame(dict2); df2
# Out:
#    Number of Topics  all-mpnet-base-v2  stsb-roberta-large  \
# 0                10              0.960               0.900
# 1                20              0.830               0.840
# 2                30              0.865               0.853
# 3                50              0.690               0.632
# 4               100              0.585               0.547
#
#    bert-based-nli-mean-tokens  all-distilroberta-v1  all-miniLM-L6-v2
# 0                       0.930                 0.920              0.88
# 1                       0.860                 0.870              0.92
# 2                       0.876                 0.806              0.82
# 3                       0.688                 0.720              0.73
# 4                       0.525                 0.548              0.56

# %%
df2.to_csv('diversity.csv')
